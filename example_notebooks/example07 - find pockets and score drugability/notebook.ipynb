# %%
# %%bash
# remove everything except this notebook
shopt -s extglob
rm -rf !("notebook.ipynb")
# to test any error in the terminal, use:
# !ipython3 -c "%run notebook.ipynb"

# %%
# !conda list | grep fpocket
# Out:
# fpocket                   4.0.2                hbb826e7_0    conda-forge

# %%
# !mkdir fpocket_output

# %%
# !cp ../ref_Jupyter_Dock/test/Blind_Docking/1XOZ_clean_H.pdb .

# %%
# !fpocket -f {'1XOZ_clean_H.pdb'} -d > {'pocket_descriptors.csv'}

# %%
import pandas as pd
pockets_data=pd.read_csv('pocket_descriptors.csv',sep=' ',index_col=[0])
pockets_data
# Out:
#         drug_score     volume  nb_asph  inter_chain  apol_asph_proportion  \
# cav_id
# 1           0.8741  1028.3990      139            0                0.6331
# 2           0.0452   560.6885       72            0                0.3333
# 3           0.0003   504.7823       37            0                0.3243
# 4           0.0021   383.0336       30            0                0.4667
# 5           0.0009   109.1321       23            0                0.3913
# 6           0.0046   224.2952       34            0                0.4706
# 7           0.0005   220.8120       16            0                0.6250
# 8           0.0004   220.2096       15            0                0.2667
# 9           0.0012   270.4959       33            0                0.6061
# 10          0.0030   649.8133       52            0                0.2500
# 11          0.0017   193.2079       26            0                0.6538
# 12          0.0014  1127.0513      107            0                0.3645
# ...
